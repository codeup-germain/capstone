# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from env import api_key

pd.set_option("display.max_rows", None, "display.max_columns", None)

pd.reset_option("display.max_rows", "display.max_columns")

import re

# %%
# use by-name request and use gamertag
response = requests.get(f"https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/battlebud?api_key={api_key}")

# %%
response.json()
# Out:
# {'id': 'wPW6si6_BrV_OC4FTi49Si2PeMbJM-7i2y2NK8tcxORSD1k',
#  'accountId': 'pRGmYwVwYy0VU1W-PRfMY_tUuwY6TikHV1clTFR-L1Jrgg',
#  'puuid': 'r9_mZslFIqwPMNiko362SeuZS7luHTEXapN_F-hpJv15KjtDipl4Z_b-YD2Mu6FvcI85MswOCXhW7A',
#  'name': 'Battlebud',
#  'profileIconId': 4404,
#  'revisionDate': 1635397171000,
#  'summonerLevel': 315}

# %%
# use puuid in by-puuid request
pro_puuid = 'r9_mZslFIqwPMNiko362SeuZS7luHTEXapN_F-hpJv15KjtDipl4Z_b-YD2Mu6FvcI85MswOCXhW7A'

# %%
# main url
url = 'https://americas.api.riotgames.com/'

# request query
query = f'lol/match/v5/matches/by-puuid/{pro_puuid}/ids?start=&count=100&api_key={api_key}'

# Get request
response = requests.get(url+query)

# %%
# unpack response Returns matchlist
#response.json()

# %%
game = 'NA1_4083906028'

# Main url
url = 'https://americas.api.riotgames.com/'

# Requesting by matches
query = f'lol/match/v5/matches/{game}/timeline/?api_key={api_key}'

# Make your request
response = requests.get(url+query)

# %%
data = response.json()

# %%
if game < 20 min
    break

# %%
df = pd.DataFrame()
for index in range(len(temp['info']['frames'])):
    for event in temp['info']['frames'][index]['events']:
        df = df.append(event, ignore_index=True)

# %%
df.timestamp = df.timestamp / 60_000

# %%
kills_df = df[df.type== 'CHAMPION_KILL']

# %%
d = {}
mylist = []
for value in kills_df.assistingParticipantIds:
    if type(value) == list:
        for assist in value:
            mylist.append(assist)
temp = pd.DataFrame(mylist)

for index, player in enumerate(kills_df.killerId.value_counts().sort_index()):
    
    # Grabbing kills and saving values to same dictionary
    d['killsplayer_'+str(int(kills_df.killerId.value_counts().sort_index().index[index]))] =\
    kills_df.killerId.value_counts().sort_index().iloc[index]

    # Grabbing deaths and saving values to same dictionary
for index, player in enumerate(kills_df.victimId.value_counts().sort_index()):
    d['deathsplayer_'+str(int(kills_df.victimId.value_counts().sort_index().index[index]))] =\
    kills_df.victimId.value_counts().sort_index().iloc[index]
    
    # Grabbing assists and saving values to same dictionary
for index, player in enumerate(temp[0].value_counts().sort_index()):
    d['assistsplayer_'+str(temp[0].value_counts().sort_index().index[index])] = temp.value_counts().sort_index().iloc[index]

# %%
#Select the particpantFrames section for the very first timeframe
players = data['info']['frames'][0]['participantFrames']
players
# Out:
# {'1': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 29,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 25,
#    'attackSpeed': 100,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 541,
#    'healthMax': 541,
#    'healthRegen': 0,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 30,
#    'movementSpeed': 335,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 200,
#    'powerMax': 200,
#    'powerRegen': 0,
#    'spellVamp': 0},
#   'currentGold': 500,
#   'damageStats': {'magicDamageDone': 0,
#    'magicDamageDoneToChampions': 0,
#    'magicDamageTaken': 0,
#    'physicalDamageDone': 0,
#    'physicalDamageDoneToChampions': 0,
#    'physicalDamageTaken': 0,
#    'totalDamageDone': 0,
#    'totalDamageDoneToChampions': 0,
#    'totalDamageTaken': 0,
#    'trueDamageDone': 0,
#    'trueDamageDoneToChampions': 0,
#    'trueDamageTaken': 0},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 1,
#   'minionsKilled': 0,
#   'participantId': 1,
#   'position': {'x': 554, 'y': 581},
#   'timeEnemySpentControlled': 0,
#   'totalGold': 500,
#   'xp': 0},
#  '2': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 38,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 25,
#    'attackSpeed': 100,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 585,
#    'healthMax': 585,
#    'healthRegen': 0,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 32,
#    'movementSpeed': 345,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 275,
#    'powerMax': 275,
#    'powerRegen': 0,
#    'spellVamp': 0},
#   'currentGold': 500,
#   'damageStats': {'magicDamageDone': 0,
#    'magicDamageDoneToChampions': 0,
#    'magicDamageTaken': 0,
#    'physicalDamageDone': 0,
#    'physicalDamageDoneToChampions': 0,
#    'physicalDamageTaken': 0,
#    'totalDamageDone': 0,
#    'totalDamageDoneToChampions': 0,
#    'totalDamageTaken': 0,
#    'trueDamageDone': 0,
#    'trueDamageDoneToChampions': 0,
#    'trueDamageTaken': 0},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 1,
#   'minionsKilled': 0,
#   'participantId': 2,
#   'position': {'x': 557, 'y': 345},
#   'timeEnemySpentControlled': 0,
#   'totalGold': 500,
#   'xp': 0},
#  '3': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 30,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 25,
#    'attackSpeed': 100,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 490,
#    'healthMax': 490,
#    'healthRegen': 0,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 32,
#    'movementSpeed': 345,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 115,
#    'powerMax': 115,
#    'powerRegen': 0,
#    'spellVamp': 0},
#   'currentGold': 500,
#   'damageStats': {'magicDamageDone': 0,
#    'magicDamageDoneToChampions': 0,
#    'magicDamageTaken': 0,
#    'physicalDamageDone': 0,
#    'physicalDamageDoneToChampions': 0,
#    'physicalDamageTaken': 0,
#    'totalDamageDone': 0,
#    'totalDamageDoneToChampions': 0,
#    'totalDamageTaken': 0,
#    'trueDamageDone': 0,
#    'trueDamageDoneToChampions': 0,
#    'trueDamageTaken': 0},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 1,
#   'minionsKilled': 0,
#   'participantId': 3,
#   'position': {'x': 335, 'y': 269},
#   'timeEnemySpentControlled': 0,
#   'totalGold': 500,
#   'xp': 0},
#  '4': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 27,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 25,
#    'attackSpeed': 100,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 612,
#    'healthMax': 612,
#    'healthRegen': 0,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 30,
#    'movementSpeed': 330,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 287,
#    'powerMax': 287,
#    'powerRegen': 0,
#    'spellVamp': 0},
#   'currentGold': 500,
#   'damageStats': {'magicDamageDone': 0,
#    'magicDamageDoneToChampions': 0,
#    'magicDamageTaken': 0,
#    'physicalDamageDone': 0,
#    'physicalDamageDoneToChampions': 0,
#    'physicalDamageTaken': 0,
#    'totalDamageDone': 0,
#    'totalDamageDoneToChampions': 0,
#    'totalDamageTaken': 0,
#    'trueDamageDone': 0,
#    'trueDamageDoneToChampions': 0,
#    'trueDamageTaken': 0},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 1,
#   'minionsKilled': 0,
#   'participantId': 4,
#   'position': {'x': 194, 'y': 457},
#   'timeEnemySpentControlled': 0,
#   'totalGold': 500,
#   'xp': 0},
#  '5': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 45,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 25,
#    'attackSpeed': 100,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 600,
#    'healthMax': 600,
#    'healthRegen': 0,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 32,
#    'movementSpeed': 330,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 415,
#    'powerMax': 415,
#    'powerRegen': 0,
#    'spellVamp': 0},
#   'currentGold': 500,
#   'damageStats': {'magicDamageDone': 0,
#    'magicDamageDoneToChampions': 0,
#    'magicDamageTaken': 0,
#    'physicalDamageDone': 0,
#    'physicalDamageDoneToChampions': 0,
#    'physicalDamageTaken': 0,
#    'totalDamageDone': 0,
#    'totalDamageDoneToChampions': 0,
#    'totalDamageTaken': 0,
#    'trueDamageDone': 0,
#    'trueDamageDoneToChampions': 0,
#    'trueDamageTaken': 0},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 1,
#   'minionsKilled': 0,
#   'participantId': 5,
#   'position': {'x': 329, 'y': 650},
#   'timeEnemySpentControlled': 0,
#   'totalGold': 500,
#   'xp': 0},
#  '6': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 23,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 25,
#    'attackSpeed': 100,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 537,
#    'healthMax': 537,
#    'healthRegen': 0,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 30,
#    'movementSpeed': 330,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 0,
#    'powerMax': 2,
#    'powerRegen': 0,
#    'spellVamp': 0},
#   'currentGold': 500,
#   'damageStats': {'magicDamageDone': 0,
#    'magicDamageDoneToChampions': 0,
#    'magicDamageTaken': 0,
#    'physicalDamageDone': 0,
#    'physicalDamageDoneToChampions': 0,
#    'physicalDamageTaken': 0,
#    'totalDamageDone': 0,
#    'totalDamageDoneToChampions': 0,
#    'totalDamageTaken': 0,
#    'trueDamageDone': 0,
#    'trueDamageDoneToChampions': 0,
#    'trueDamageTaken': 0},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 1,
#   'minionsKilled': 0,
#   'participantId': 6,
#   'position': {'x': 14180, 'y': 14271},
#   'timeEnemySpentControlled': 0,
#   'totalGold': 500,
#   'xp': 0},
#  '7': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 30,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 25,
#    'attackSpeed': 100,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 585,
#    'healthMax': 585,
#    'healthRegen': 0,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 32,
#    'movementSpeed': 340,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 295,
#    'powerMax': 295,
#    'powerRegen': 0,
#    'spellVamp': 0},
#   'currentGold': 500,
#   'damageStats': {'magicDamageDone': 0,
#    'magicDamageDoneToChampions': 0,
#    'magicDamageTaken': 0,
#    'physicalDamageDone': 0,
#    'physicalDamageDoneToChampions': 0,
#    'physicalDamageTaken': 0,
#    'totalDamageDone': 0,
#    'totalDamageDoneToChampions': 0,
#    'totalDamageTaken': 0,
#    'trueDamageDone': 0,
#    'trueDamageDoneToChampions': 0,
#    'trueDamageTaken': 0},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 1,
#   'minionsKilled': 0,
#   'participantId': 7,
#   'position': {'x': 14176, 'y': 14506},
#   'timeEnemySpentControlled': 0,
#   'totalGold': 500,
#   'xp': 0},
#  '8': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 19,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 25,
#    'attackSpeed': 100,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 490,
#    'healthMax': 490,
#    'healthRegen': 0,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 30,
#    'movementSpeed': 330,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 480,
#    'powerMax': 480,
#    'powerRegen': 0,
#    'spellVamp': 0},
#   'currentGold': 500,
#   'damageStats': {'magicDamageDone': 0,
#    'magicDamageDoneToChampions': 0,
#    'magicDamageTaken': 0,
#    'physicalDamageDone': 0,
#    'physicalDamageDoneToChampions': 0,
#    'physicalDamageTaken': 0,
#    'totalDamageDone': 0,
#    'totalDamageDoneToChampions': 0,
#    'totalDamageTaken': 0,
#    'trueDamageDone': 0,
#    'trueDamageDoneToChampions': 0,
#    'trueDamageTaken': 0},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 1,
#   'minionsKilled': 0,
#   'participantId': 8,
#   'position': {'x': 14398, 'y': 14582},
#   'timeEnemySpentControlled': 0,
#   'totalGold': 500,
#   'xp': 0},
#  '9': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 28,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 25,
#    'attackSpeed': 100,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 570,
#    'healthMax': 570,
#    'healthRegen': 0,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 30,
#    'movementSpeed': 325,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 300,
#    'powerMax': 300,
#    'powerRegen': 0,
#    'spellVamp': 0},
#   'currentGold': 500,
#   'damageStats': {'magicDamageDone': 0,
#    'magicDamageDoneToChampions': 0,
#    'magicDamageTaken': 0,
#    'physicalDamageDone': 0,
#    'physicalDamageDoneToChampions': 0,
#    'physicalDamageTaken': 0,
#    'totalDamageDone': 0,
#    'totalDamageDoneToChampions': 0,
#    'totalDamageTaken': 0,
#    'trueDamageDone': 0,
#    'trueDamageDoneToChampions': 0,
#    'trueDamageTaken': 0},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 1,
#   'minionsKilled': 0,
#   'participantId': 9,
#   'position': {'x': 14539, 'y': 14394},
#   'timeEnemySpentControlled': 0,
#   'totalGold': 500,
#   'xp': 0},
#  '10': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 25,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 25,
#    'attackSpeed': 100,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 480,
#    'healthMax': 480,
#    'healthRegen': 0,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 25,
#    'movementSpeed': 330,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 400,
#    'powerMax': 400,
#    'powerRegen': 0,
#    'spellVamp': 0},
#   'currentGold': 500,
#   'damageStats': {'magicDamageDone': 0,
#    'magicDamageDoneToChampions': 0,
#    'magicDamageTaken': 0,
#    'physicalDamageDone': 0,
#    'physicalDamageDoneToChampions': 0,
#    'physicalDamageTaken': 0,
#    'totalDamageDone': 0,
#    'totalDamageDoneToChampions': 0,
#    'totalDamageTaken': 0,
#    'trueDamageDone': 0,
#    'trueDamageDoneToChampions': 0,
#    'trueDamageTaken': 0},
#   'goldPerSecond': 0,
#   'jungleMinionsKilled': 0,
#   'level': 1,
#   'minionsKilled': 0,
#   'participantId': 10,
#   'position': {'x': 14404, 'y': 14201},
#   'timeEnemySpentControlled': 0,
#   'totalGold': 500,
#   'xp': 0}}

# %%
#Now that I have been able to get the player stats in one time frame,
#Create a loop to get the rest

#I will need a list to store all the dictionaries from each timeframe
player_stats = []

#Here, each timeframe represents about one minute
for timeframe in data['info']['frames']:
    players = timeframe['participantFrames']
    
    #Now create a dicitonary to hold the players' stats from this timeframe
    players_dict = {}
    
    for i in range(1, len(players) + 1):
        #Now create a temp dict to store the current players stats
        #Use formatted strings to automatically increment the player label
        temp_dict = {
            f'currentGold_{i}': players[str(i)]['currentGold'],
            f'magicDamageDoneToChampions_{i}': players[str(i)]['damageStats']['magicDamageDoneToChampions'],
            f'physicalDamageDoneToChampions_{i}': players[str(i)]['damageStats']['physicalDamageDoneToChampions'],
            f'trueDamageDoneToChampions_{i}': players[str(i)]['damageStats']['trueDamageDoneToChampions'],
            f'totalDamageDoneToChampions_{i}': players[str(i)]['damageStats']['totalDamageDoneToChampions'],
            f'goldPerSecond_{i}': players[str(i)]['goldPerSecond'],
            f'jungleMinionsKilled_{i}': players[str(i)]['jungleMinionsKilled'],
            f'level_{i}': players[str(i)]['level'],
            f'minionsKilled_{i}': players[str(i)]['minionsKilled'],
            f'timeEnemySpentControlled_{i}': players[str(i)]['timeEnemySpentControlled'],
            f'totalGold_{i}': players[str(i)]['totalGold'],
            f'xp_{i}': players[str(i)]['xp']
        }

        #Now that I have the current players stats, extend it to the overall players_dict
        players_dict.update(temp_dict)
        
    #Update the players_dict one more time with the timestamp for the timeframe
    players_dict.update({'timestamp' : timeframe['timestamp']})
    
    #Append the players_dict to the overall player_stats list of dicts
    player_stats.append(players_dict)

# %%
player_stats[1]
# Out:
# {'currentGold_1': 1505,
#  'magicDamageDoneToChampions_1': 6877,
#  'physicalDamageDoneToChampions_1': 1805,
#  'trueDamageDoneToChampions_1': 519,
#  'totalDamageDoneToChampions_1': 9202,
#  'goldPerSecond_1': 0,
#  'jungleMinionsKilled_1': 4,
#  'level_1': 11,
#  'minionsKilled_1': 82,
#  'timeEnemySpentControlled_1': 48996,
#  'totalGold_1': 7330,
#  'xp_1': 8186,
#  'currentGold_2': 222,
#  'magicDamageDoneToChampions_2': 227,
#  'physicalDamageDoneToChampions_2': 3595,
#  'trueDamageDoneToChampions_2': 0,
#  'totalDamageDoneToChampions_2': 3822,
#  'goldPerSecond_2': 0,
#  'jungleMinionsKilled_2': 111,
#  'level_2': 11,
#  'minionsKilled_2': 19,
#  'timeEnemySpentControlled_2': 360748,
#  'totalGold_2': 7572,
#  'xp_2': 8574,
#  'currentGold_3': 1948,
#  'magicDamageDoneToChampions_3': 659,
#  'physicalDamageDoneToChampions_3': 6823,
#  'trueDamageDoneToChampions_3': 678,
#  'totalDamageDoneToChampions_3': 8160,
#  'goldPerSecond_3': 0,
#  'jungleMinionsKilled_3': 10,
#  'level_3': 12,
#  'minionsKilled_3': 110,
#  'timeEnemySpentControlled_3': 68123,
#  'totalGold_3': 8458,
#  'xp_3': 8826,
#  'currentGold_4': 1270,
#  'magicDamageDoneToChampions_4': 0,
#  'physicalDamageDoneToChampions_4': 9816,
#  'trueDamageDoneToChampions_4': 1539,
#  'totalDamageDoneToChampions_4': 11356,
#  'goldPerSecond_4': 0,
#  'jungleMinionsKilled_4': 0,
#  'level_4': 10,
#  'minionsKilled_4': 118,
#  'timeEnemySpentControlled_4': 99371,
#  'totalGold_4': 8545,
#  'xp_4': 6831,
#  'currentGold_5': 961,
#  'magicDamageDoneToChampions_5': 0,
#  'physicalDamageDoneToChampions_5': 3655,
#  'trueDamageDoneToChampions_5': 968,
#  'totalDamageDoneToChampions_5': 4624,
#  'goldPerSecond_5': 30,
#  'jungleMinionsKilled_5': 0,
#  'level_5': 10,
#  'minionsKilled_5': 30,
#  'timeEnemySpentControlled_5': 63011,
#  'totalGold_5': 6311,
#  'xp_5': 6318,
#  'currentGold_6': 75,
#  'magicDamageDoneToChampions_6': 8644,
#  'physicalDamageDoneToChampions_6': 168,
#  'trueDamageDoneToChampions_6': 540,
#  'totalDamageDoneToChampions_6': 9352,
#  'goldPerSecond_6': 0,
#  'jungleMinionsKilled_6': 0,
#  'level_6': 12,
#  'minionsKilled_6': 110,
#  'timeEnemySpentControlled_6': 58851,
#  'totalGold_6': 6725,
#  'xp_6': 8786,
#  'currentGold_7': 1271,
#  'magicDamageDoneToChampions_7': 0,
#  'physicalDamageDoneToChampions_7': 3564,
#  'trueDamageDoneToChampions_7': 240,
#  'totalDamageDoneToChampions_7': 3804,
#  'goldPerSecond_7': 0,
#  'jungleMinionsKilled_7': 61,
#  'level_7': 9,
#  'minionsKilled_7': 15,
#  'timeEnemySpentControlled_7': 114877,
#  'totalGold_7': 5521,
#  'xp_7': 5775,
#  'currentGold_8': 2042,
#  'magicDamageDoneToChampions_8': 2530,
#  'physicalDamageDoneToChampions_8': 127,
#  'trueDamageDoneToChampions_8': 0,
#  'totalDamageDoneToChampions_8': 2658,
#  'goldPerSecond_8': 0,
#  'jungleMinionsKilled_8': 0,
#  'level_8': 11,
#  'minionsKilled_8': 113,
#  'timeEnemySpentControlled_8': 310642,
#  'totalGold_8': 5097,
#  'xp_8': 7335,
#  'currentGold_9': 477,
#  'magicDamageDoneToChampions_9': 459,
#  'physicalDamageDoneToChampions_9': 6695,
#  'trueDamageDoneToChampions_9': 210,
#  'totalDamageDoneToChampions_9': 7365,
#  'goldPerSecond_9': 0,
#  'jungleMinionsKilled_9': 0,
#  'level_9': 10,
#  'minionsKilled_9': 117,
#  'timeEnemySpentControlled_9': 41620,
#  'totalGold_9': 6422,
#  'xp_9': 6208,
#  'currentGold_10': 1070,
#  'magicDamageDoneToChampions_10': 3305,
#  'physicalDamageDoneToChampions_10': 1095,
#  'trueDamageDoneToChampions_10': 602,
#  'totalDamageDoneToChampions_10': 5003,
#  'goldPerSecond_10': 30,
#  'jungleMinionsKilled_10': 0,
#  'level_10': 8,
#  'minionsKilled_10': 3,
#  'timeEnemySpentControlled_10': 29330,
#  'totalGold_10': 4570,
#  'xp_10': 4941,
#  'timestamp': 1066945}

# %%
final_d = d.copy()

# %%
final_d.update(player_stats[20])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-82-ea7cade609c7> in <module>
# ----> 1 final_d.update(player_stats[20])
#
# IndexError: list index out of range

# %%
df = pd.DataFrame()

# %%
df.append(final_d, ignore_index=True)
# Out:
#    assistsplayer_1  assistsplayer_10  assistsplayer_2  assistsplayer_3  \
# 0              5.0               3.0              6.0              6.0
#
#    assistsplayer_5  assistsplayer_7  assistsplayer_8  assistsplayer_9  \
# 0              9.0              2.0              3.0              2.0
#
#    currentGold_1  currentGold_10  currentGold_2  currentGold_3  currentGold_4  \
# 0         1505.0          1070.0          222.0         1948.0         1270.0
#
#    currentGold_5  currentGold_6  currentGold_7  currentGold_8  currentGold_9  \
# 0          961.0           75.0         1271.0         2042.0          477.0
#
#    deathsplayer_1  deathsplayer_10  deathsplayer_3  deathsplayer_4  \
# 0             4.0              4.0             3.0             2.0
#
#    deathsplayer_5  deathsplayer_6  deathsplayer_7  deathsplayer_8  \
# 0             1.0             4.0             5.0             7.0
#
#    deathsplayer_9  goldPerSecond_1  goldPerSecond_10  goldPerSecond_2  \
# 0             5.0              0.0              30.0              0.0
#
#    goldPerSecond_3  goldPerSecond_4  goldPerSecond_5  goldPerSecond_6  \
# 0              0.0              0.0             30.0              0.0
#
#    goldPerSecond_7  goldPerSecond_8  goldPerSecond_9  jungleMinionsKilled_1  \
# 0              0.0              0.0              0.0                    4.0
#
#    jungleMinionsKilled_10  jungleMinionsKilled_2  jungleMinionsKilled_3  \
# 0                     0.0                  111.0                   10.0
#
#    jungleMinionsKilled_4  jungleMinionsKilled_5  jungleMinionsKilled_6  \
# 0                    0.0                    0.0                    0.0
#
#    jungleMinionsKilled_7  jungleMinionsKilled_8  jungleMinionsKilled_9  \
# 0                   61.0                    0.0                    0.0
#
#    killsplayer_1  killsplayer_10  killsplayer_2  killsplayer_3  killsplayer_4  \
# 0            5.0             1.0            2.0            4.0           12.0
#
#    killsplayer_5  killsplayer_6  killsplayer_7  killsplayer_9  level_1  \
# 0            2.0            4.0            2.0            3.0     11.0
#
#    level_10  level_2  level_3  level_4  level_5  level_6  level_7  level_8  \
# 0       8.0     11.0     12.0     10.0     10.0     12.0      9.0     11.0
#
#    level_9  magicDamageDoneToChampions_1  magicDamageDoneToChampions_10  \
# 0     10.0                        6877.0                         3305.0
#
#    magicDamageDoneToChampions_2  magicDamageDoneToChampions_3  \
# 0                         227.0                         659.0
#
#    magicDamageDoneToChampions_4  magicDamageDoneToChampions_5  \
# 0                           0.0                           0.0
#
#    magicDamageDoneToChampions_6  magicDamageDoneToChampions_7  \
# 0                        8644.0                           0.0
#
#    magicDamageDoneToChampions_8  magicDamageDoneToChampions_9  \
# 0                        2530.0                         459.0
#
#    minionsKilled_1  minionsKilled_10  minionsKilled_2  minionsKilled_3  \
# 0             82.0               3.0             19.0            110.0
#
#    minionsKilled_4  minionsKilled_5  minionsKilled_6  minionsKilled_7  \
# 0            118.0             30.0            110.0             15.0
#
#    minionsKilled_8  minionsKilled_9  physicalDamageDoneToChampions_1  \
# 0            113.0            117.0                           1805.0
#
#    physicalDamageDoneToChampions_10  physicalDamageDoneToChampions_2  \
# 0                            1095.0                           3595.0
#
#    physicalDamageDoneToChampions_3  physicalDamageDoneToChampions_4  \
# 0                           6823.0                           9816.0
#
#    physicalDamageDoneToChampions_5  physicalDamageDoneToChampions_6  \
# 0                           3655.0                            168.0
#
#    physicalDamageDoneToChampions_7  physicalDamageDoneToChampions_8  \
# 0                           3564.0                            127.0
#
#    physicalDamageDoneToChampions_9  timeEnemySpentControlled_1  \
# 0                           6695.0                     48996.0
#
#    timeEnemySpentControlled_10  timeEnemySpentControlled_2  \
# 0                      29330.0                    360748.0
#
#    timeEnemySpentControlled_3  timeEnemySpentControlled_4  \
# 0                     68123.0                     99371.0
#
#    timeEnemySpentControlled_5  timeEnemySpentControlled_6  \
# 0                     63011.0                     58851.0
#
#    timeEnemySpentControlled_7  timeEnemySpentControlled_8  \
# 0                    114877.0                    310642.0
#
#    timeEnemySpentControlled_9  timestamp  totalDamageDoneToChampions_1  \
# 0                     41620.0  1066945.0                        9202.0
#
#    totalDamageDoneToChampions_10  totalDamageDoneToChampions_2  \
# 0                         5003.0                        3822.0
#
#    totalDamageDoneToChampions_3  totalDamageDoneToChampions_4  \
# 0                        8160.0                       11356.0
#
#    totalDamageDoneToChampions_5  totalDamageDoneToChampions_6  \
# 0                        4624.0                        9352.0
#
#    totalDamageDoneToChampions_7  totalDamageDoneToChampions_8  \
# 0                        3804.0                        2658.0
#
#    totalDamageDoneToChampions_9  totalGold_1  totalGold_10  totalGold_2  \
# 0                        7365.0       7330.0        4570.0       7572.0
#
#    totalGold_3  totalGold_4  totalGold_5  totalGold_6  totalGold_7  \
# 0       8458.0       8545.0       6311.0       6725.0       5521.0
#
#    totalGold_8  totalGold_9  trueDamageDoneToChampions_1  \
# 0       5097.0       6422.0                        519.0
#
#    trueDamageDoneToChampions_10  trueDamageDoneToChampions_2  \
# 0                         602.0                          0.0
#
#    trueDamageDoneToChampions_3  trueDamageDoneToChampions_4  \
# 0                        678.0                       1539.0
#
#    trueDamageDoneToChampions_5  trueDamageDoneToChampions_6  \
# 0                        968.0                        540.0
#
#    trueDamageDoneToChampions_7  trueDamageDoneToChampions_8  \
# 0                        240.0                          0.0
#
#    trueDamageDoneToChampions_9    xp_1   xp_10    xp_2    xp_3    xp_4  \
# 0                        210.0  8186.0  4941.0  8574.0  8826.0  6831.0
#
#      xp_5    xp_6    xp_7    xp_8    xp_9
# 0  6318.0  8786.0  5775.0  7335.0  6208.0
