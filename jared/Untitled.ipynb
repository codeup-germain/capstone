# %%
import pandas as pd

# %%
df = pd.read_csv("2640_players.csv")

# %%
list(df.players)
# Out:
# ['Ahwii',
#  'Blazze',
#  'Prabhably',
#  'Dark Rose Vayne',
#  'hyperton',
#  'Oner v2',
#  'Jqckpot',
#  'ConTraiCungCuaMe',
#  'Dodge my Lantern',
#  'llllllllllllIIll',
#  'CaiShiYuanZuiQAQ',
#  'Smiling Devil',
#  'RoseThorn',
#  'SlayYourGame',
#  'Spyy',
#  'IlIlIIIlIlIlII',
#  'WaIlDashin',
#  'Fiku',
#  'Prototype white',
#  'john nguyen suck',
#  'do b top gap',
#  'sparklol',
#  'Big WheeI',
#  'Levi Pug',
#  'Z Score',
#  'VoidStar',
#  'Everest76',
#  'LlL TOP',
#  'Cendilion',
#  'RIPStollie',
#  'Hot Ruffles8 ',
#  'Nebulus',
#  'GrayFawx',
#  'Nee8',
#  'ttv 7Wylly7',
#  'Shieda Kayn',
#  'HelImet',
#  'Shroomologist',
#  'align my chakras',
#  'Injustable',
#  'enchant3r',
#  'pawn0',
#  'ArticXII',
#  'EQon111',
#  'Mystery Bunny',
#  'Arkaynn',
#  'RobbyBob',
#  'Arrogant',
#  'XiOnG XiOnG GuAl',
#  'FGNERF2010',
#  'for sky',
#  'cogii',
#  'EricZYang',
#  'hi im fam',
#  'KissFight',
#  'stray kid',
#  'Suna Shogun Sama',
#  'zeroz',
#  'WayneDwops',
# ...
