# %%
import pandas as pd
import numpy as np
import env
import acquire

# %%
df = acquire.acquire()

# %%
df
# Out:
#       Unnamed: 0  assistsplayer_1  assistsplayer_10  assistsplayer_2  \
# 0              0              2.0               3.0              3.0
# 1              1              1.0              15.0              3.0
# 2              2              0.0               5.0              4.0
# 3              3              3.0               4.0              0.0
# 4              4              3.0               4.0              6.0
# ...          ...              ...               ...              ...
# 4731        4731              1.0               4.0              1.0
# 4732        4732              0.0               8.0              3.0
# 4733        4733              2.0               9.0              4.0
# 4734        4734              4.0               5.0              3.0
# 4735        4735              4.0               9.0              2.0
#
#       assistsplayer_3  assistsplayer_4  assistsplayer_5  assistsplayer_6  \
# ...
